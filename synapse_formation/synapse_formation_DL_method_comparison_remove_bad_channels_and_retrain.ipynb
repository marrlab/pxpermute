# %% [markdown]
# # Classification of synapses
#
# In this jupyter notebook, we provide an example of how to extract explainable features and run a classification for the imaging flow cytometry dataset provided by:
#
# scifAI: An explainable AI python framework for the analysis of multi-channel imaging flow cytometry data
#
#
# We assume you have already installed the library. Otherwise you can install it using
#
# `!pip -q install <Path to the cloned module>`
#
# This notebook provides an example for deep learning methods

# %% [markdown]
# here we import a series of needed modules.

# %%
import scifAI
import numpy as np
from sklearn.datasets import make_classification
import torch.nn as nn
from skorch import NeuralNetClassifier
import matplotlib.pyplot as plt
import glob
from imageio import imread
# Ignore warnings
import warnings
warnings.filterwarnings("ignore")
import os
import numpy as np
from tqdm import tqdm
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
import torch
from torchvision import transforms
from IPython.core.debugger import Tracer
from torch.utils.data import DataLoader, Dataset
from sklearn.pipeline import Pipeline, FeatureUnion
# Compare Algorithms
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

# %%
from scifAI.dl.utils import calculate_weights, get_statistics
from scifAI.dl.dataset import DatasetGenerator
from scifAI.dl.custom_transforms import ShuffleChannel
from scifAI.dl.models import PretrainedModel, resnet18

# %%
from skorch.callbacks import LRScheduler,Checkpoint,EpochScoring,EarlyStopping
import torch.optim as optim
from skorch.helper import predefined_split

# %% [markdown]
# here, we provide a function for visualizing the result of the confusion matrix which will be used later.

# %%
from sklearn.metrics import (plot_confusion_matrix, 
                             matthews_corrcoef, 
                             classification_report,
                             confusion_matrix, 
                             accuracy_score, 
                             balanced_accuracy_score, 
                             cohen_kappa_score, 
                             f1_score,  
                             precision_score, recall_score)

def classification_complete_report(y_true, y_pred, plot = True ): 
    print(classification_report(y_true, y_pred))
    print(15*"----")
    print("matthews correlation coeff: %.2f" % (matthews_corrcoef(y_true, y_pred)) )
    print("Cohen Kappa score: %.2f" % (cohen_kappa_score(y_true, y_pred)) )
    print("Accuracy: %.2f & balanced Accuracy: %.2f" % (accuracy_score(y_true, y_pred), balanced_accuracy_score(y_true, y_pred)) )
    print("macro F1 score: %.2f & micro F1 score: %.2f" % (f1_score(y_true, y_pred, average = "macro"), f1_score(y_true, y_pred, average = "micro")) )
    print("macro Precision score: %.2f & micro Precision score: %.2f" % (precision_score(y_true, y_pred, average = "macro"), precision_score(y_true, y_pred, average = "micro")) )
    print("macro Recall score: %.2f & micro Recall score: %.2f" % (recall_score(y_true, y_pred, average = "macro"), recall_score(y_true, y_pred, average = "micro")) )
    print(15*"----")

# %% [markdown]
# now lets calculate the metadata:

# %%
# %%time

metadata = pd.read_csv("/projects/site/pred/data_science/year/2022/immunological_synapse/synapse_data_features/metadata_subset.csv.gz")

metadata.file = metadata.file.str.replace("/pstore/data/DS4/", "/projects/site/pred/data_science/year/2022/immunological_synapse/")
# Out:
# CPU times: user 2.61 s, sys: 170 ms, total: 2.78 s
# Wall time: 2.81 s

# %%
row_index = metadata.set.isin(["train","validation","test"]) 

metadata = metadata.loc[row_index,:].reset_index(drop = True)

metadata
# Out:
#                                                    file    experiment  \
# 0     /projects/site/pred/data_science/year/2022/imm...  Experiment_1
# 1     /projects/site/pred/data_science/year/2022/imm...  Experiment_1
# 2     /projects/site/pred/data_science/year/2022/imm...  Experiment_1
# 3     /projects/site/pred/data_science/year/2022/imm...  Experiment_1
# 4     /projects/site/pred/data_science/year/2022/imm...  Experiment_1
# ...                                                 ...           ...
# 5216  /projects/site/pred/data_science/year/2022/imm...  Experiment_4
# 5217  /projects/site/pred/data_science/year/2022/imm...  Experiment_4
# 5218  /projects/site/pred/data_science/year/2022/imm...  Experiment_4
# 5219  /projects/site/pred/data_science/year/2022/imm...  Experiment_4
# 5220  /projects/site/pred/data_science/year/2022/imm...  Experiment_4
#
#         donor condition  object_number         set  \
# 0     Donor_1      +SEA           4147       train
# 1     Donor_1      +SEA          57117       train
# 2     Donor_1      +SEA          48521        test
# 3     Donor_1      +SEA          30947       train
# 4     Donor_1      +SEA          38634       train
# ...       ...       ...            ...         ...
# 5216  Donor_9      -SEA          22111       train
# 5217  Donor_9      -SEA          28850  validation
# 5218  Donor_9      -SEA          11855        test
# 5219  Donor_9      -SEA          18171       train
# 5220  Donor_9      -SEA          15013       train
#
#                              label
# 0                           B_cell
# 1            B_T_cell_in_one_layer
# 2            B_T_cell_in_one_layer
# 3                       Multiplets
# 4                           B_cell
# ...                            ...
# 5216                    Multiplets
# 5217      No_cell_cell_interaction
# 5218         T_cell_with_signaling
# 5219      No_cell_cell_interaction
# 5220  T_cell_with_B_cell_fragments
#
# [5221 rows x 7 columns]

# %%
print(metadata.label.unique())
metadata.label.hist()
# Out:
# ['B_cell' 'B_T_cell_in_one_layer' 'Multiplets' 'Synapses_with_signaling'
#  'T_cell_with_B_cell_fragments' 'T_cell' 'No_cell_cell_interaction'
#  'Synapses_without_signaling' 'T_cell_with_signaling']
# <AxesSubplot:>

# %% [markdown]
# lets plot a random image per class

# %%
from skimage.util import crop
import h5py

def crop_pad_h_w(image_dummy,reshape_size):
    if image_dummy.shape[0] < reshape_size:
        h1_pad = ( reshape_size - image_dummy.shape[0])/2
        h1_pad = int(h1_pad)
        h2_pad =  reshape_size - h1_pad - image_dummy.shape[0]
        h1_crop = 0
        h2_crop = 0
    else:
        h1_pad = 0
        h2_pad = 0
        h1_crop = ( reshape_size - image_dummy.shape[0])/2
        h1_crop = abs(int(h1_crop))
        h2_crop = image_dummy.shape[0]- reshape_size  - h1_crop

    if image_dummy.shape[1] < reshape_size:
        w1_pad = (reshape_size - image_dummy.shape[1])/2
        w1_pad = int(w1_pad)
        w2_pad = reshape_size - w1_pad - image_dummy.shape[1]
        w1_crop = 0
        w2_crop = 0
    else:
        w1_pad = 0
        w2_pad = 0
        w1_crop = (reshape_size - image_dummy.shape[1])/2
        w1_crop = abs(int(w1_crop))
        w2_crop = image_dummy.shape[1]- reshape_size  - w1_crop

    h = [h1_crop, h2_crop, h1_pad, h2_pad]
    w = [w1_crop, w2_crop, w1_pad, w2_pad] 
    return h, w

def plot_images_with_metadata(metadata,  
                              figsize = None,
                              channels = ["BF","BF", "BF"],
                    channel_colors =  ["Greys", "Oranges", "Blues"],
                    image_size = 128):
    
    metadata_dummy = metadata.copy()
    metadata_dummy = metadata_dummy.reset_index(drop = True)
    
    nrows = len(metadata_dummy)
    ncols = len(channel_colors)
    
    if figsize is None:
        figsize = ( ncols*2, nrows*2 )
    fix,ax = plt.subplots(nrows, ncols, figsize = figsize, tight_layout = True)
    
    vmin = [4095.]*ncols
    vmax = [0.]*ncols
    
    for i in range(nrows):
        h5_file_ = h5py.File(metadata_dummy.loc[i,"file"], "r")
        image = h5_file_.get("image")[()]
        for j, ch in enumerate(range(ncols)):
            vmin[j] = min(vmin[j], image[:,:,ch].min()  )
            vmax[j] = max(vmax[j], image[:,:,ch].max()  )
        
    for i in range(nrows):
        h5_file_ = h5py.File(metadata_dummy.loc[i,"file"], "r")
        image = h5_file_.get("image")[()]         
        
        h, w = crop_pad_h_w(image, image_size)
        h1_crop, h2_crop, h1_pad, h2_pad =  h 
        w1_crop, w2_crop, w1_pad, w2_pad = w 
        for j, ch in enumerate(channel_colors):
            image_dummy = crop(image[:,:,j], ((h1_crop,h2_crop),(w1_crop,w2_crop)))            
            image_dummy = np.pad(image_dummy, 
                                     ((h1_pad,h2_pad),(w1_pad,w2_pad)), 
                                     'constant', 
                                     constant_values = np.mean(image_dummy) )
            ax[i,j].imshow(image_dummy, cmap = channel_colors[j] , vmin = vmin[j], vmax = vmax[j]  )
            ax[i,j].set_xticks([])
            ax[i,j].set_yticks([])
            
            if j == 0:
                print(metadata_dummy.loc[i,"label"])
                ax[i,j].set_ylabel(metadata_dummy.loc[i,"label"])
            if i == 0:
                ax[i,j].set_xlabel(channels[j])
                ax[i,j].xaxis.set_label_position('top') 
            
        h5_file_.close()
    plt.tight_layout()

    
plot_images_with_metadata(metadata.groupby('label').apply(lambda s: s.sample(1, random_state = 3)).reset_index(drop = True) ,  
                              figsize = (8,len(metadata.label.unique())),
                          channels = ["BF","Antibody","CD18","F-Actin","MHCII","CD3","P-CD3zeta","Live-Dead"],
                    channel_colors =  ["Greys", "copper", "copper", "copper", "copper", "copper", "copper", "copper"],
                    image_size = 128)
# Out:
# B_T_cell_in_one_layer
# B_cell
# Multiplets
# No_cell_cell_interaction
# Synapses_with_signaling
# Synapses_without_signaling
# T_cell
# T_cell_with_B_cell_fragments
# T_cell_with_signaling

# %% [markdown]
# Set all random seeds to the specific value, so the results are more reproducable

# %%
seed_value = 42

os.environ['PYTHONHASHSEED']=str(seed_value)
import random
random.seed(seed_value)

np.random.seed(seed_value)
torch.manual_seed(seed_value)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# Define all necessary parameters

# %%
model_dir = "models"
log_dir = "logs"
scaling_factor = 4095.
reshape_size = 160

# %%
batch_size = 128
num_workers = 4
device="cuda"

# %%
channel_importance = pd.read_csv("channel_importance.csv")

# %%
from sklearn.preprocessing import MinMaxScaler
interpretation_methods = ["PXPermute", "Occlusion", "GuidedGradCAM", "DeepLift", "IntegratedGradients", "LRP"]
channel_importance.loc[:, interpretation_methods] = MinMaxScaler().fit_transform(channel_importance.loc[:, interpretation_methods])

channel_importance
# Out:
#     fold    channel  PXPermute  DeepLift       LRP  GuidedGradCAM  \
# 0      1         BF   0.161485  0.362150  0.482151       0.154770
# 1      1   Antibody   0.121280  0.431038  0.615916       0.582579
# 2      1       CD18   0.125171  0.237442  0.484931       0.524043
# 3      1    F-Actin   0.111648  0.202214  0.493383       0.327392
# 4      1      MHCII   0.659918  0.421273  0.567049       0.000000
# 5      1        CD3   1.000000  0.210269  0.460546       0.302400
# 6      1  P-CD3zeta   0.811514  0.279507  0.859905       0.660856
# 7      1  Live-Dead   0.101375  0.398805  0.610754       0.691084
# 8      3         BF   0.015130  0.529919  0.667253       0.819149
# 9      3   Antibody   0.054948  0.322012  0.550609       0.667404
# 10     3       CD18   0.085330  0.339229  0.550878       0.667153
# 11     3    F-Actin   0.158718  0.288577  0.366466       0.677521
# 12     3      MHCII   0.499604  0.183431  0.483245       0.775707
# 13     3        CD3   0.716906  0.353184  0.599778       0.383484
# 14     3  P-CD3zeta   0.860043  0.241477  0.501560       0.664578
# 15     3  Live-Dead   0.000896  0.313381  0.529934       0.855764
# 16     2         BF   0.023997  0.410408  0.793480       0.705738
# 17     2   Antibody   0.052511  0.307496  0.361365       0.708703
# 18     2       CD18   0.106667  0.180030  0.298707       0.679643
# 19     2    F-Actin   0.177156  0.275179  0.379245       0.732371
# 20     2      MHCII   0.490318  0.176611  0.184106       0.891190
# 21     2        CD3   0.504499  0.949217  1.000000       0.055190
# 22     2  P-CD3zeta   0.775620  1.000000  0.639787       1.000000
# 23     2  Live-Dead   0.000000  0.435520  0.000000       0.854811
# 24     5         BF   0.007471  0.229391  0.458099       0.670473
# 25     5   Antibody   0.010376  0.329696  0.507888       0.704759
# 26     5       CD18   0.043080  0.221222  0.448527       0.769735
# 27     5    F-Actin   0.084203  0.238590  0.549072       0.694637
# 28     5      MHCII   0.570142  0.294206  0.528130       0.829023
# 29     5        CD3   0.560557  0.317170  0.529655       0.370825
# 30     5  P-CD3zeta   0.649158  0.317376  0.047702       0.872948
# 31     5  Live-Dead   0.021019  0.374261  0.567494       0.698589
# 32     4         BF   0.025363  0.440871  0.457499       0.846704
# 33     4   Antibody   0.053564  0.352265  0.473057       0.521231
# 34     4       CD18   0.006852  0.307661  0.540615       0.703082
# 35     4    F-Actin   0.280011  0.243771  0.452996       0.670256
# 36     4      MHCII   0.467443  0.197862  0.539515       0.617018
# 37     4        CD3   0.769563  0.451917  0.486084       0.412792
# 38     4  P-CD3zeta   0.777476  0.362785  0.233681       0.790212
# 39     4  Live-Dead   0.001401  0.000000  0.440378       0.765398
#
#     IntegratedGradients  Occlusion
# 0              0.278642   0.086404
# 1              0.273206   0.088344
# 2              0.247015   0.037002
# 3              0.205009   0.013363
# 4              0.380313   0.250058
# 5              0.195405   0.954592
# 6              0.214588   0.317143
# 7              0.449760   0.121222
# 8              0.447298   0.051435
# 9              0.331210   0.052035
# 10             0.325198   0.110277
# 11             0.280453   0.067018
# 12             0.154029   0.391683
# 13             0.385286   1.000000
# 14             0.283505   0.351722
# 15             0.206567   0.048358
# 16             0.251390   0.043821
# 17             0.172784   0.081138
# 18             0.188363   0.062605
# 19             0.291064   0.045120
# 20             0.188558   0.283969
# 21             1.000000   0.862999
# 22             0.747538   0.363312
# 23             0.387478   0.075475
# 24             0.000000   0.064104
# 25             0.314952   0.013943
# 26             0.320609   0.078518
# 27             0.249270   0.023183
# 28             0.244654   0.350133
# 29             0.443678   0.753259
# 30             0.398891   0.289828
# 31             0.111654   0.066559
# 32             0.445325   0.014879
# 33             0.258782   0.030044
# 34             0.308066   0.015319
# 35             0.193733   0.146121
# 36             0.187053   0.344234
# 37             0.416984   0.874501
# 38             0.208512   0.342288
# 39             0.013618   0.000000

# %%
import seaborn as sns
sns.barplot(data = pd.melt(channel_importance, id_vars=["fold","channel"]), 
            x = "variable", 
            y = "value",
            order = interpretation_methods,
            hue = "channel")
# Out:
# <AxesSubplot:xlabel='variable', ylabel='value'>

# %%
sns.heatmap(channel_importance.groupby(["channel"]).mean().loc[:,interpretation_methods], cmap = "Greys")
# Out:
# <AxesSubplot:ylabel='channel'>

# %%
def select_top_channels(channel_importance, method, num_top_channels):
    grouped_importance = channel_importance.loc[:,["channel",method]].groupby("channel").mean()
    grouped_importance = grouped_importance.sort_values(by=method, ascending = False) 
    selected_channels = grouped_importance.index[:num_top_channels]
    selected_channels = [int(ch.replace("Ch","")) for ch in selected_channels]
    return selected_channels

# %%
class AddGaussianNoise(object):
    def __init__(self, mean=0., std=1.):
        self.std = std
        self.mean = mean
        
    def __call__(self, tensor):
        return tensor + torch.randn(tensor.size()) * self.std + self.mean
    
    def __repr__(self):
        return self.__class__.__name__ + '(mean={0}, std={1})'.format(self.mean, self.std)
    
class MinMaxScaler(object):
    def __init__(self, min_in , max_in, min_out, max_out):
        self.min_in = min_in.reshape(-1,1,1)
        self.max_in = max_in.reshape(-1,1,1)
        self.min_out = min_out
        self.max_out = max_out
        
    def __call__(self, tensor):
        
        tensor_ = (tensor - self.min_in)/(self.max_in - self.min_in)
        tensor_ = tensor_*(self.max_out - self.min_out) + self.min_out
        tensor_[tensor_<self.min_out]= self.min_out
        tensor_[tensor_>self.max_out]= self.max_out
        return tensor_
    
    def __repr__(self):
        return self.__class__.__name__ + '(min_out={0}, max_out={1})'.format(self.min_out, self.max_out)

# %%
def get_statistics(dataloader, selected_channels, device="cuda"):
    nmb_channels = len(selected_channels)

    statistics = dict()
    statistics["p01"] = torch.zeros(nmb_channels).to(device)
    statistics["p99"] = torch.zeros(nmb_channels).to(device)
    for data_l in dataloader:
        image, _ = data_l
        image = image.to(device)
        for n in range(nmb_channels):
            statistics["p01"][n] += torch.quantile(image[:, n, :, :], 0.01)
            statistics["p99"][n] += torch.quantile(image[:, n, :, :], 0.99)

    # averaging
    for k in statistics:
        statistics[k] = statistics[k].div_(len(dataloader))
        statistics[k] = statistics[k].to("cpu")

    print('statistics used: %s' % (str(statistics)))

    return statistics

# %%
set_of_interesting_classes = metadata.label.unique().tolist()
label_map = dict(zip(sorted(set(set_of_interesting_classes)), np.arange(len(set(set_of_interesting_classes)))))

# %%
channel_importance.channel = channel_importance.channel.replace({
    "BF":"Ch0",
    "Antibody":"Ch1",
    "CD18":"Ch2",
    "F-Actin":"Ch3",
    "MHCII":"Ch4",
    "CD3":"Ch5",
    "P-CD3zeta":"Ch6",
    "Live-Dead":"Ch7",
})

# %%
channel_importance.channel.unique()
# Out:
# array(['Ch0', 'Ch1', 'Ch2', 'Ch3', 'Ch4', 'Ch5', 'Ch6', 'Ch7'],
#       dtype=object)

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
import torch.nn as nn
from scifAI.dl.models import PretrainedModel
import torch.nn.functional as F

num_all_channels = len(channel_importance.channel.unique())

try:
    results_with_best_channels = pd.read_csv("results_with_best_channels_remove_bad_channels_and_retrain.csv")
    results_with_best_channels["num_channels"] = results_with_best_channels.loc[:,channel_importance.channel.unique().tolist()].astype(int).sum(1)
except:
    results_with_best_channels = pd.DataFrame(columns = ["method",
                                                         "f1_micro",
                                                         "f1_macro",
                                                         "accuracy",
                                                        "fold_num"] + channel_importance.channel.unique().tolist())


for met in interpretation_methods:
    for num_top_channels in reversed((range(1,num_all_channels+1))):
        selected_channels = select_top_channels(channel_importance, met , num_top_channels)
        selected_channels.sort()
        train_index, test_index, _, _ = train_test_split(metadata.index, 
                                                        metadata.label.tolist(), 
                                                        stratify = metadata.label.tolist(),
                                                        test_size=0.2, 
                                                        shuffle=True,
                                                        random_state=seed_value)
        skf = StratifiedKFold(n_splits=5,shuffle=False)
        fold_num = 1
        for train_index, validation_index in skf.split(train_index.tolist(), 
                                metadata.loc[train_index, "label"].replace(label_map)):
            row_index = results_with_best_channels["method"] == met
            row_index = row_index & (results_with_best_channels["fold_num"] == fold_num)
            row_index = row_index & (results_with_best_channels["num_channels"] == num_top_channels)
            
            print(met, selected_channels, fold_num)
            
            if row_index.sum() == 1:
                print("this combination has been previsouly studied")
            else:

                print("sizes: train", len(train_index), 
                      "validation", len(validation_index), 
                      "sizes: test", len(test_index))


                train_dataset = DatasetGenerator(metadata=metadata.loc[train_index,:],
                                             label_map=label_map,
                                             selected_channels=selected_channels,
                                             scaling_factor=scaling_factor,
                                             reshape_size=reshape_size,
                                             transform=transforms.Compose([ ] ))
                train_loader = DataLoader(train_dataset, 
                                          batch_size=batch_size,
                                          shuffle=False,
                                          num_workers=num_workers,
                                          pin_memory=True)
                statistics = get_statistics(train_loader, selected_channels=selected_channels)
                train_loader = None

                stats = dict()
                stats["lower_bound"] = statistics['p01']
                stats["upper_bound"] = statistics['p99']

                train_transform = [ 
                            MinMaxScaler(           min_in =  stats["lower_bound"] , 
                                                    max_in =  stats["upper_bound"] , 
                                                    min_out =  0. , 
                                                    max_out =  1.),
                            transforms.RandomHorizontalFlip(),
                            transforms.RandomVerticalFlip(),
                            AddGaussianNoise(mean=0., std=0.01),
                    ]

                validation_transform =  [ 
                            MinMaxScaler(           min_in =  stats["lower_bound"] , 
                                                    max_in =  stats["upper_bound"] , 
                                                    min_out =  0. , 
                                                    max_out =  1.),
                    ]

                test_transform =  [ 
                            MinMaxScaler(           min_in =  stats["lower_bound"] , 
                                                    max_in =  stats["upper_bound"] , 
                                                    min_out =  0. , 
                                                    max_out =  1.),
                    ]


                train_dataset = DatasetGenerator(metadata=metadata.loc[train_index,:],
                                             label_map=label_map,
                                             selected_channels=selected_channels,
                                             scaling_factor=scaling_factor, 
                                             reshape_size=reshape_size,
                                             transform= transforms.Compose(train_transform))

                validation_dataset = DatasetGenerator(metadata=metadata.loc[validation_index,:],
                                             label_map=label_map,
                                             selected_channels=selected_channels,
                                             scaling_factor=scaling_factor, 
                                             reshape_size=reshape_size,
                                             transform= transforms.Compose(validation_transform))

                test_dataset = DatasetGenerator(metadata=metadata.loc[test_index,:],
                                             label_map=label_map,
                                             selected_channels=selected_channels,
                                             scaling_factor=scaling_factor, 
                                             reshape_size=reshape_size,
                                             transform= transforms.Compose(test_transform))

                print("initializing a model with,", len(selected_channels),
                      "channels and", len(set_of_interesting_classes), "classses")
                resnet18_modified = PretrainedModel(num_channels = len(selected_channels),
                                                    num_classes = len(set_of_interesting_classes), 
                                                    pretrained = True)

                lr_scheduler = LRScheduler(policy='ReduceLROnPlateau', factor=0.5, patience=5)

                epoch_scoring_f1_micro = EpochScoring("f1_micro", 
                                                 name =  "valid_f1_micro", 
                                                 on_train = False,
                                                 lower_is_better = False)

                epoch_scoring_f1_macro = EpochScoring("f1_macro", 
                                                 name =  "valid_f1_macro", 
                                                 on_train = False,
                                                 lower_is_better = False)

                early_stopping = EarlyStopping(monitor='valid_f1_macro', 
                                                   patience=30, 
                                                   threshold=0.0001, 
                                                   threshold_mode='rel', 
                                                   lower_is_better=False)

                checkpoint = Checkpoint(f_params='synapse_formation_DL_method_comparison_remove_bad_channels_and_retrain.pth',
                                            monitor='valid_f1_macro_best', load_best=True)

                net = NeuralNetClassifier(    
                        resnet18_modified.cuda(), 
                        criterion=nn.CrossEntropyLoss,
                        lr=0.001,
                        batch_size=batch_size,
                        max_epochs=1000,
                        optimizer=optim.Adam,
                        iterator_train__shuffle=True,
                        iterator_train__num_workers=num_workers,
                        iterator_valid__shuffle=False,
                        iterator_valid__num_workers=2,
                        callbacks=[lr_scheduler, epoch_scoring_f1_micro, 
                                   epoch_scoring_f1_macro, 
                                   early_stopping, checkpoint],
                        train_split=predefined_split(validation_dataset),
                        device="cuda",
                        verbose=0,
                        warm_start=True)
                net = net.fit(train_dataset, y = None)

                net.module.load_state_dict(torch.load('synapse_formation_DL_method_comparison_remove_bad_channels_and_retrain.pth')) 


                preds = net.predict(test_dataset)

                results = {
                    "method":met,
                    "f1_micro":f1_score(test_dataset.metadata.label.replace(label_map), preds, average="micro"),
                    "f1_macro":f1_score(test_dataset.metadata.label.replace(label_map), preds, average="macro"),
                    "accuracy":accuracy_score(test_dataset.metadata.label.replace(label_map), preds),
                    "fold_num":fold_num
                }

                for ch in range(num_all_channels):
                    if ch in selected_channels:
                        results["Ch"+str(ch)] = 1
                    else:
                        results["Ch"+str(ch)] = 0

                results_with_best_channels = results_with_best_channels.append(results,ignore_index = True)

                print(results_with_best_channels.groupby("method").mean())
                net = None
                resnet18_modified = None
                torch.cuda.empty_cache()
                results_with_best_channels.to_csv("results_with_best_channels_remove_bad_channels_and_retrain.csv", index = False)
            
            print("---------------------------"*3)
            fold_num = fold_num + 1
# Out:
# PXPermute [0, 1, 2, 3, 4, 5, 6, 7] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [0, 1, 2, 3, 4, 5, 6, 7] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [0, 1, 2, 3, 4, 5, 6, 7] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [0, 1, 2, 3, 4, 5, 6, 7] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [0, 1, 2, 3, 4, 5, 6, 7] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [0, 1, 2, 3, 4, 5, 6] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [0, 1, 2, 3, 4, 5, 6] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [0, 1, 2, 3, 4, 5, 6] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [0, 1, 2, 3, 4, 5, 6] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [0, 1, 2, 3, 4, 5, 6] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [1, 2, 3, 4, 5, 6] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [1, 2, 3, 4, 5, 6] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [1, 2, 3, 4, 5, 6] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [1, 2, 3, 4, 5, 6] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [1, 2, 3, 4, 5, 6] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [2, 3, 4, 5, 6] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [2, 3, 4, 5, 6] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [2, 3, 4, 5, 6] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [2, 3, 4, 5, 6] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [2, 3, 4, 5, 6] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [3, 4, 5, 6] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [3, 4, 5, 6] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [3, 4, 5, 6] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [3, 4, 5, 6] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [3, 4, 5, 6] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [4, 5, 6] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [4, 5, 6] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [4, 5, 6] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [4, 5, 6] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [4, 5, 6] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [5, 6] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [5, 6] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [5, 6] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [5, 6] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [5, 6] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [6] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [6] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [6] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [6] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# PXPermute [6] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [0, 1, 2, 3, 4, 5, 6, 7] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [0, 1, 2, 3, 4, 5, 6, 7] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [0, 1, 2, 3, 4, 5, 6, 7] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [0, 1, 2, 3, 4, 5, 6, 7] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [0, 1, 2, 3, 4, 5, 6, 7] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [1, 2, 3, 4, 5, 6, 7] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [1, 2, 3, 4, 5, 6, 7] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [1, 2, 3, 4, 5, 6, 7] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [1, 2, 3, 4, 5, 6, 7] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [1, 2, 3, 4, 5, 6, 7] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [2, 3, 4, 5, 6, 7] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [2, 3, 4, 5, 6, 7] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [2, 3, 4, 5, 6, 7] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [2, 3, 4, 5, 6, 7] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [2, 3, 4, 5, 6, 7] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [2, 4, 5, 6, 7] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [2, 4, 5, 6, 7] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [2, 4, 5, 6, 7] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [2, 4, 5, 6, 7] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [2, 4, 5, 6, 7] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [4, 5, 6, 7] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [4, 5, 6, 7] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [4, 5, 6, 7] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [4, 5, 6, 7] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [4, 5, 6, 7] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [4, 5, 6] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [4, 5, 6] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [4, 5, 6] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [4, 5, 6] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [4, 5, 6] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [5, 6] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [5, 6] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [5, 6] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [5, 6] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [5, 6] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [5] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [5] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [5] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [5] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# Occlusion [5] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [0, 1, 2, 3, 4, 5, 6, 7] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [0, 1, 2, 3, 4, 5, 6, 7] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [0, 1, 2, 3, 4, 5, 6, 7] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [0, 1, 2, 3, 4, 5, 6, 7] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [0, 1, 2, 3, 4, 5, 6, 7] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [0, 1, 2, 3, 4, 6, 7] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [0, 1, 2, 3, 4, 6, 7] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [0, 1, 2, 3, 4, 6, 7] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [0, 1, 2, 3, 4, 6, 7] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [0, 1, 2, 3, 4, 6, 7] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [0, 1, 2, 4, 6, 7] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [0, 1, 2, 4, 6, 7] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [0, 1, 2, 4, 6, 7] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [0, 1, 2, 4, 6, 7] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [0, 1, 2, 4, 6, 7] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [0, 1, 2, 6, 7] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [0, 1, 2, 6, 7] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [0, 1, 2, 6, 7] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [0, 1, 2, 6, 7] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [0, 1, 2, 6, 7] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [0, 2, 6, 7] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [0, 2, 6, 7] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [0, 2, 6, 7] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [0, 2, 6, 7] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [0, 2, 6, 7] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [2, 6, 7] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [2, 6, 7] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [2, 6, 7] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [2, 6, 7] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [2, 6, 7] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [6, 7] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [6, 7] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [6, 7] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [6, 7] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [6, 7] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [6] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [6] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [6] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [6] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# GuidedGradCAM [6] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [0, 1, 2, 3, 4, 5, 6, 7] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [0, 1, 2, 3, 4, 5, 6, 7] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [0, 1, 2, 3, 4, 5, 6, 7] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [0, 1, 2, 3, 4, 5, 6, 7] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [0, 1, 2, 3, 4, 5, 6, 7] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [0, 1, 2, 4, 5, 6, 7] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [0, 1, 2, 4, 5, 6, 7] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [0, 1, 2, 4, 5, 6, 7] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [0, 1, 2, 4, 5, 6, 7] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [0, 1, 2, 4, 5, 6, 7] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [0, 1, 2, 5, 6, 7] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [0, 1, 2, 5, 6, 7] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [0, 1, 2, 5, 6, 7] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [0, 1, 2, 5, 6, 7] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [0, 1, 2, 5, 6, 7] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [0, 1, 5, 6, 7] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [0, 1, 5, 6, 7] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [0, 1, 5, 6, 7] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [0, 1, 5, 6, 7] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [0, 1, 5, 6, 7] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [0, 1, 5, 6] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [0, 1, 5, 6] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [0, 1, 5, 6] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [0, 1, 5, 6] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [0, 1, 5, 6] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [0, 5, 6] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [0, 5, 6] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [0, 5, 6] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [0, 5, 6] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [0, 5, 6] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [5, 6] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [5, 6] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [5, 6] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [5, 6] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [5, 6] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [5] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [5] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [5] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [5] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# DeepLift [5] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [0, 1, 2, 3, 4, 5, 6, 7] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [0, 1, 2, 3, 4, 5, 6, 7] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [0, 1, 2, 3, 4, 5, 6, 7] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [0, 1, 2, 3, 4, 5, 6, 7] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [0, 1, 2, 3, 4, 5, 6, 7] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [0, 1, 2, 3, 5, 6, 7] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [0, 1, 2, 3, 5, 6, 7] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [0, 1, 2, 3, 5, 6, 7] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [0, 1, 2, 3, 5, 6, 7] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [0, 1, 2, 3, 5, 6, 7] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [0, 1, 2, 3, 5, 6] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [0, 1, 2, 3, 5, 6] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [0, 1, 2, 3, 5, 6] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [0, 1, 2, 3, 5, 6] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [0, 1, 2, 3, 5, 6] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [0, 1, 2, 5, 6] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [0, 1, 2, 5, 6] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [0, 1, 2, 5, 6] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [0, 1, 2, 5, 6] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [0, 1, 2, 5, 6] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [0, 2, 5, 6] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [0, 2, 5, 6] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [0, 2, 5, 6] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [0, 2, 5, 6] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [0, 2, 5, 6] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [0, 5, 6] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [0, 5, 6] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [0, 5, 6] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [0, 5, 6] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [0, 5, 6] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [5, 6] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [5, 6] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [5, 6] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [5, 6] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [5, 6] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [5] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [5] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [5] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [5] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# IntegratedGradients [5] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [0, 1, 2, 3, 4, 5, 6, 7] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [0, 1, 2, 3, 4, 5, 6, 7] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [0, 1, 2, 3, 4, 5, 6, 7] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [0, 1, 2, 3, 4, 5, 6, 7] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [0, 1, 2, 3, 4, 5, 6, 7] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [0, 1, 2, 3, 4, 5, 6] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [0, 1, 2, 3, 4, 5, 6] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [0, 1, 2, 3, 4, 5, 6] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [0, 1, 2, 3, 4, 5, 6] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [0, 1, 2, 3, 4, 5, 6] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [0, 1, 2, 4, 5, 6] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [0, 1, 2, 4, 5, 6] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [0, 1, 2, 4, 5, 6] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [0, 1, 2, 4, 5, 6] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [0, 1, 2, 4, 5, 6] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [0, 1, 2, 4, 5] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [0, 1, 2, 4, 5] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [0, 1, 2, 4, 5] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [0, 1, 2, 4, 5] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [0, 1, 2, 4, 5] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [0, 1, 2, 5] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [0, 1, 2, 5] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [0, 1, 2, 5] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [0, 1, 2, 5] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [0, 1, 2, 5] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [0, 1, 5] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [0, 1, 5] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [0, 1, 5] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [0, 1, 5] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [0, 1, 5] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [0, 5] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [0, 5] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [0, 5] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [0, 5] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [0, 5] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [5] 1
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [5] 2
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [5] 3
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [5] 4
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------
# LRP [5] 5
# this combination has been previsouly studied
# ---------------------------------------------------------------------------------

# %%
results_with_best_channels
# Out:
#         method  f1_micro  f1_macro  accuracy  fold_num  Ch0  Ch1  Ch2  Ch3  \
# 0    PXPermute  0.946411  0.944807  0.946411         1    1    1    1    1
# 1    PXPermute  0.939713  0.938323  0.939713         2    1    1    1    1
# 2    PXPermute  0.957895  0.956336  0.957895         3    1    1    1    1
# 3    PXPermute  0.949282  0.948063  0.949282         4    1    1    1    1
# 4    PXPermute  0.947368  0.945941  0.947368         5    1    1    1    1
# ..         ...       ...       ...       ...       ...  ...  ...  ...  ...
# 235        LRP  0.699522  0.691206  0.699522         1    0    0    0    0
# 236        LRP  0.764593  0.760975  0.764593         2    0    0    0    0
# 237        LRP  0.813397  0.809635  0.813397         3    0    0    0    0
# 238        LRP  0.706220  0.696095  0.706220         4    0    0    0    0
# 239        LRP  0.754067  0.742649  0.754067         5    0    0    0    0
#
#      Ch4  Ch5  Ch6  Ch7  num_channels
# 0      1    1    1    1             8
# 1      1    1    1    1             8
# 2      1    1    1    1             8
# 3      1    1    1    1             8
# 4      1    1    1    1             8
# ..   ...  ...  ...  ...           ...
# 235    0    1    0    0             1
# 236    0    1    0    0             1
# 237    0    1    0    0             1
# 238    0    1    0    0             1
# 239    0    1    0    0             1
#
# [240 rows x 14 columns]

# %%
results_with_best_channels["num_channels"] = results_with_best_channels.loc[:,channel_importance.channel.unique().tolist()].astype(int).sum(1)
results_with_best_channels["num_channels"] = 8 - results_with_best_channels["num_channels"]

# %%
 results_with_best_channels
# Out:
#         method  f1_micro  f1_macro  accuracy  fold_num  Ch0  Ch1  Ch2  Ch3  \
# 0    PXPermute  0.946411  0.944807  0.946411         1    1    1    1    1
# 1    PXPermute  0.939713  0.938323  0.939713         2    1    1    1    1
# 2    PXPermute  0.957895  0.956336  0.957895         3    1    1    1    1
# 3    PXPermute  0.949282  0.948063  0.949282         4    1    1    1    1
# 4    PXPermute  0.947368  0.945941  0.947368         5    1    1    1    1
# ..         ...       ...       ...       ...       ...  ...  ...  ...  ...
# 235        LRP  0.699522  0.691206  0.699522         1    0    0    0    0
# 236        LRP  0.764593  0.760975  0.764593         2    0    0    0    0
# 237        LRP  0.813397  0.809635  0.813397         3    0    0    0    0
# 238        LRP  0.706220  0.696095  0.706220         4    0    0    0    0
# 239        LRP  0.754067  0.742649  0.754067         5    0    0    0    0
#
#      Ch4  Ch5  Ch6  Ch7  num_channels
# 0      1    1    1    1             0
# 1      1    1    1    1             0
# 2      1    1    1    1             0
# 3      1    1    1    1             0
# 4      1    1    1    1             0
# ..   ...  ...  ...  ...           ...
# 235    0    1    0    0             7
# 236    0    1    0    0             7
# 237    0    1    0    0             7
# 238    0    1    0    0             7
# 239    0    1    0    0             7
#
# [240 rows x 14 columns]

# %%
print(results_with_best_channels.groupby("method").mean().round(2))
# Out:
#                      f1_micro  f1_macro  accuracy  fold_num   Ch0   Ch1   Ch2  \
# method
# DeepLift                 0.89      0.89      0.89       3.0  0.75  0.62  0.38
# GuidedGradCAM            0.91      0.90      0.91       3.0  0.62  0.50  0.75
# IntegratedGradients      0.89      0.88      0.89       3.0  0.75  0.50  0.62
# LRP                      0.86      0.86      0.86       3.0  0.88  0.75  0.62
# Occlusion                0.90      0.89      0.90       3.0  0.12  0.25  0.50
# PXPermute                0.92      0.92      0.92       3.0  0.25  0.38  0.50
#
#                       Ch3   Ch4   Ch5   Ch6   Ch7  num_channels
# method
# DeepLift             0.12  0.25  1.00  0.88  0.50           3.5
# GuidedGradCAM        0.25  0.38  0.12  1.00  0.88           3.5
# IntegratedGradients  0.38  0.12  1.00  0.88  0.25           3.5
# LRP                  0.25  0.50  1.00  0.38  0.12           3.5
# Occlusion            0.38  0.75  1.00  0.88  0.62           3.5
# PXPermute            0.62  0.75  0.88  1.00  0.12           3.5

# %%
print(results_with_best_channels.groupby("method").std().round(2))
# Out:
#                      f1_micro  f1_macro  accuracy  fold_num   Ch0   Ch1   Ch2  \
# method
# DeepLift                 0.07      0.07      0.07      1.43  0.44  0.49  0.49
# GuidedGradCAM            0.05      0.05      0.05      1.43  0.49  0.51  0.44
# IntegratedGradients      0.07      0.07      0.07      1.43  0.44  0.51  0.49
# LRP                      0.08      0.08      0.08      1.43  0.33  0.44  0.49
# Occlusion                0.08      0.08      0.08      1.43  0.33  0.44  0.51
# PXPermute                0.04      0.04      0.04      1.43  0.44  0.49  0.51
#
#                       Ch3   Ch4   Ch5   Ch6   Ch7  num_channels
# method
# DeepLift             0.33  0.44  0.00  0.33  0.51          2.32
# GuidedGradCAM        0.44  0.49  0.33  0.00  0.33          2.32
# IntegratedGradients  0.49  0.33  0.00  0.33  0.44          2.32
# LRP                  0.44  0.51  0.00  0.49  0.33          2.32
# Occlusion            0.49  0.44  0.00  0.33  0.49          2.32
# PXPermute            0.49  0.44  0.33  0.00  0.33          2.32

# %% [markdown]
# now we calculate the statistics of every channel to later use for nomalizing the dataset

# %%
import seaborn as sns

fig, ax = plt.subplots(figsize=(10,5))
ax = sns.lineplot(data = results_with_best_channels, 
            x = "num_channels", 
            y = "f1_micro",
                  hue="method",
                  err_style="bars",
                  errorbar=("se", 2),
                 ax=ax)

ax.set_ylim(0.6,1)
# Out:
# (0.6, 1.0)

# %%
results_with_best_channels.to_csv("results_with_best_channels_remove_bad_channels_and_retrain.csv", index = False)

# %%
1
# Out:
# 1
